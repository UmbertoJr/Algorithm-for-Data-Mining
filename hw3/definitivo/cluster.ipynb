# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
users = pd.read_csv('BX-Users.csv', sep=';', encoding='latin-1')

# %%
users['Location_ID']=le.fit_transform(users.Location)

# %%
users.sort('Location')
# Out:
# C:\Users\Umbertojunior\Desktop\applicazioni usate\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#         User-ID                                           Location   Age  \
# 118659   118660                  &#19978;&#28023;, shanghai, china  25.0
# 116874   116875  &#19978;&#28023;/&#21488;&#24030;/&#36335;&#26...  25.0
# 267048   267049  &#20013;&#22269;&#24191;&#19996;&#30465;&#2426...   NaN
# 245967   245968  &#20013;&#22269;&#27993;&#27743;&#30465;&#2770...  17.0
# 272618   272619   &#20013;&#23665;&#24066;, puerto rico, hong kong   NaN
# 206114   206115          &#20020;&#28023;, &#27993;&#27743;, china   NaN
# 278077   278078  &#20029;&#27743;, &#20013;&#22269;-&#20113;&#2...   NaN
# 204009   204010             &#20061;&#27743;, connecticut, croatia  18.0
# 220008   220009                   &#20975;&#37324;, guizhou, china  18.0
# ...
