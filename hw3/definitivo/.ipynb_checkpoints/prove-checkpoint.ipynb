# %%
import pandas as pd
import numpy as np
import my_lib as lb2
import Lil_lib as lb
import scipy.sparse as sp
import re

# %%
ratings=pd.read_csv('BX-Book-Ratings.csv',sep=';', encoding='latin-1')
books = pd.read_csv('BX-Books_mod.csv',sep=';', encoding='latin-1')
users = pd.read_csv('BX-Users.csv', sep=';', encoding='latin-1')

# %%
def trova(word):
    return bool(re.search('Harry',word, re.I))

# %%
books[books['Book-Title'].apply(trova)]
# Out:
#               ISBN                                         Book-Title  \
# 821     0767908473  The Sorcerer's Companion: A Guide to the Magic...
# 2143    059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 2809    0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 3459    0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 3839    0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 5431    0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 5432    0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 5506    043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 6330    0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 6658    0312950489   The Black Echo (Detective Harry Bosch Mysteries)
# 6933    0439139600       Harry Potter and the Goblet of Fire (Book 4)
# 9027    043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
ratings['book_ID']=le.fit_transform(ratings.ISBN)
ratings['user_ID']=le.fit_transform(ratings['User-ID'])

# %%
group = ratings.groupby('user_ID')

# %%
us, bo =map(len , [ratings.user_ID.unique() , ratings.book_ID.unique()])

# %%
piv = sp.lil_matrix((us,bo))
for line in ratings.itertuples():
    piv[line[5],line[4]]= line[3]

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating  book_ID  user_ID
# 0   276725  034545104X            0    57188   104433
# 1   276726  0155061224            5    29750   104434
# 2   276727  0446520802            0   107392   104435
# 3   276729  052165615X            3   127253   104436
# 4   276729  0521795028            6   127287   104436

# %%
ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'book_ID', 'user_ID'], dtype='object')

# %%
group.get_group(us)[['book_ID','Book-Rating']]
# Out:
#       book_ID  Book-Rating
# 9561    32069            0

# %%
us
# Out:
# 0

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5 , random_state=1)

# %%
kf.get_n_splits(ratings)
# Out:
# 5

# %%
print(kf)
# Out:
# KFold(n_splits=5, random_state=1, shuffle=False)

# %%
for ti , te in kf.split(ratings):
# Out:
# 919824 229956 1149779 229955
# 919824 229956 1149779 459911
# 919824 229956 1149779 689867
# 919824 229956 1149779 919823
# 919824 229956 919823 1149779

# %%
from math import sqrt
def RMSE(test,res):
    l=test.shape[0]
    return sqrt((test['Book-Rating'].values - res)**2/l)

# %%
ratings['Book-Rating'].values
# Out:
# array([ 0,  5,  0, ..., 10, 10,  8], dtype=int64)

# %%
ratings.shape[0]
# Out:
# 1149780

# %%
a = pd.Series([2])

# %%
for ind, it in ratings[]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})

# %%
grouped = df.groupby(df.A)

# %%
for index, i in grouped.get_group('bar')['B'].iteritems(): print(index , i)
# Out:
# 1 one
# 3 three
# 5 two

# %%
for i in grouped.groups: print(i)
# Out:
# foo
# bar

# %%
grouped.name

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.591923 -1.913841
# 1  bar    one  0.574137  0.169184
# 2  foo    two -1.345014  0.656667
# 3  bar  three  0.372245 -0.651302
# 4  foo    two -0.796444  0.649144
# 5  bar    two -0.076866 -0.133761
# 6  foo    one  0.984250 -0.514533
# 7  foo  three  0.682034  0.857505
